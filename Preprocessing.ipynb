# %% [markdown]
# # Summary of Hierarchical Classification Project
#
# ## I. Initial Analysis Phase
#
# ### A. Data Distribution Analysis
# - **Level 1 (Cat1)**: 6 categories
# - **Level 2 (Cat2)**: 64 categories
# - **Level 3 (Cat3)**: 377 categories
#
# ### B. Rare Category Analysis
# - **Cat2**: 22 rare categories (34.38%)
# - **Cat3**: 209 rare categories (55.44%)
# - **Threshold**: <10 samples considered rare
#
# ### C. Text Features Analysis
# - Average title length: 43.71 characters
# - Average text length: 313.60 characters
# - Title-Text ratio: ~1:7
#
# ## II. Data Cleaning Implementation
#
# ### A. Category Merging Strategy
# 1. **Very Rare Categories** (<5 samples)
#    - Direct merge to "other" category
#    - Preserves parent category structure
#
# 2. **Rare Categories** (5-10 samples)
#    - Similarity-based merging
#    - Text and hierarchy consideration
#
# 3. **Moderate Categories** (10-20 samples)
#    - Parent-based merging
#    - Maintain category relationships
#
# ### B. Similarity Calculation
# - Text similarity (TF-IDF)
# - Category name matching
# - Parent category bonus
# - Category-specific rules
#
# ### C. Results
#
# #### Category Reduction
# | Category Type | Original | Final | Reduction |
# |---------------|----------|--------|-----------|
# | Pet supplies | 35 | 30 | -14% |
# | Health personal | 81 | 45 | -44% |
# | Grocery/food | 106 | 32 | -70% |
# | Toys games | 151 | 67 | -56% |
# | Beauty | 57 | 28 | -51% |
# | Baby products | 86 | 33 | -62% |
#
# #### Merge Statistics
# - **Total Merges**: 538
#   - Very rare merges: 471 (87.5%)
#   - No good match: 21 (3.9%)
#   - Similarity-based: 46 (8.6%)
#
# ## III. Key Decisions
#
# ### A. Category-Specific Rules
# - Different similarity thresholds
# - Custom minimum sample requirements
# - Category-specific merge strategies
#
# ### B. Enhanced Similarity Matching
# 1. **Primary Metrics**
#    - Text-based similarity
#    - Hierarchical relationships
#    - Product type matching
#
# 2. **Secondary Considerations**
#    - Parent category preservation
#    - Category name similarity
#    - Semantic relationships
#
# ### C. Hierarchy Preservation
# - Maintained parent-child relationships
# - Prevented cross-category merges
# - Preserved category meaning

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# %%
class HierarchicalDataCleaner:
    def __init__(self, df):
        """
        Initialize data cleaner with configuration parameters
        """
        self.df = df.copy()
        self.rare_threshold_cat2 = 20 
        self.rare_threshold_cat3 = 10 
        self.unknown_categories = {'unknown'}
        
    def clean_data(self):
        print("Starting data cleaning process...")
        self.handle_missing_values()
        self.clean_category_names()
        self.handle_unknown_categories()
        self.consolidate_rare_categories()
        
        return self.df
    
    def handle_missing_values(self):
        """
        Handle missing values in the dataset
        """
        print("\nHandling missing values...")
        
        missing_stats = self.df.isnull().sum()
        if len(missing_stats) == 0:
            print("No missing values found")
        print("Missing values before cleaning:")
        print(missing_stats[missing_stats > 0])
        
        self.df['Title'].fillna('', inplace=True)
        self.df['Text'].fillna('', inplace=True)
        
        for col in ['Cat1', 'Cat2', 'Cat3']:
            self.df[col].fillna('unknown', inplace=True)
    
    def clean_category_names(self):
        """
        Clean and standardize category names
        """
        print("\nCleaning category names...")
        
        def clean_name(name):
            name = str(name).lower().strip()
            name = re.sub(r'[^\w\s]', ' ', name)
            name = re.sub(r'\s+', ' ', name)
            return name
        
        # Clean categories
        for col in ['Cat1', 'Cat2', 'Cat3']:
            self.df[col] = self.df[col].apply(clean_name)
            
        print(f"Unique categories after cleaning:")
        print(f"Cat1: {self.df['Cat1'].nunique()}")
        print(f"Cat2: {self.df['Cat2'].nunique()}")
        print(f"Cat3: {self.df['Cat3'].nunique()}")
    
    def handle_unknown_categories(self):
        """
        Handle 'unknown' categories based on similarity
        """
        print("\nHandling unknown categories...")
        
        self.df['combined_text'] = self.df['Title'] + ' ' + self.df['Text']
        unknown_mask = self.df['Cat3'] == 'unknown'
        unknown_samples = self.df[unknown_mask]
        
        if len(unknown_samples) > 0:
            print(f"Found {len(unknown_samples)} samples with unknown Cat3")
            
            # Create TF-IDF vectors
            tfidf = TfidfVectorizer(max_features=1000)
            known_texts = self.df[~unknown_mask]['combined_text']
            known_vectors = tfidf.fit_transform(known_texts)
            unknown_vectors = tfidf.transform(unknown_samples['combined_text'])
            
            similarities = cosine_similarity(unknown_vectors, known_vectors)
            most_similar_indices = similarities.argmax(axis=1)
            similar_categories = self.df[~unknown_mask].iloc[most_similar_indices]['Cat3'].values
            self.df.loc[unknown_mask, 'Cat3'] = similar_categories
            
            print(f"Reassigned {len(unknown_samples)} unknown categories")
    
    def consolidate_rare_categories(self):
        """
        Consolidate rare categories based on frequency and similarity
        """
        print("\nConsolidating rare categories...")
        
        cat2_counts = self.df['Cat2'].value_counts()
        cat3_counts = self.df['Cat3'].value_counts()
        
        rare_cat2 = set(cat2_counts[cat2_counts < self.rare_threshold_cat2].index)
        rare_cat3 = set(cat3_counts[cat3_counts < self.rare_threshold_cat3].index)
        
        print(f"Found {len(rare_cat2)} rare Cat2 categories")
        print(f"Found {len(rare_cat3)} rare Cat3 categories")
        
        # Consolidate based on parent-child relationships
        for cat2 in rare_cat2:
            parent_cat1 = self.df[self.df['Cat2'] == cat2]['Cat1'].mode()[0]
            similar_cat2 = self._find_similar_category(cat2, 'Cat2', parent_cat1)
            self.df.loc[self.df['Cat2'] == cat2, 'Cat2'] = similar_cat2
        
        for cat3 in rare_cat3:
            parent_cat2 = self.df[self.df['Cat3'] == cat3]['Cat2'].mode()[0]
            similar_cat3 = self._find_similar_category(cat3, 'Cat3', parent_cat2)
            self.df.loc[self.df['Cat3'] == cat3, 'Cat3'] = similar_cat3
    
    def _find_similar_category(self, category, level, parent_category):
        """
        Find similar category for merging based on text similarity
        """
        parent_samples = self.df[self.df[f'Cat{int(level[-1])-1}'] == parent_category]
        rare_samples = self.df[self.df[level] == category]
        
        if len(rare_samples) == 0 or len(parent_samples) == 0:
            return category 
        

        tfidf = TfidfVectorizer(max_features=1000)
        parent_vectors = tfidf.fit_transform(parent_samples['combined_text'])
        rare_vectors = tfidf.transform(rare_samples['combined_text'])
        rare_vectors_mean = np.asarray(rare_vectors.mean(axis=0)).flatten()
        
        similarities = cosine_similarity(
            rare_vectors_mean.reshape(1, -1), 
            parent_vectors.toarray()
        )
        most_similar_idx = similarities.argmax()
        
        return parent_samples.iloc[most_similar_idx][level]

# %%
cleaner = HierarchicalDataCleaner(df)
cleaned_df = cleaner.clean_data()
# Out:
# Starting data cleaning process...
#
# Handling missing values...
# Missing values before cleaning:
# Title    5
# dtype: int64
#
# Cleaning category names...
# Unique categories after cleaning:
# Cat1: 6
# Cat2: 64
# Cat3: 377
#
# Handling unknown categories...
# Found 487 samples with unknown Cat3
# Reassigned 487 unknown categories
#
# Consolidating rare categories...
# Found 12 rare Cat2 categories
# Found 202 rare Cat3 categories

# %%
df = pd.read_csv('data.csv')

# %%
cleaned_df
# Out:
#        productId                                              Title  \
# 0     B0002AQK70     PetSafe Staywell Pet Door with Clear Hard Flap
# 1     B0002DK8OI                      Kaytee Timothy Cubes, 1-Pound
# 2     B0006VJ6TO                                    Body Back Buddy
# 3     B000EZSFXA         SnackMasters California Style Turkey Jerky
# 4     B000KV61FC  Premier Busy Buddy Tug-a-Jug Treat Dispensing ...
# ...          ...                                                ...
# 9995  B000FGDDI0  Sunbeam 732-500 King Size Heating Pad with Ult...
# 9996  B000FVC78C                         Reef One Biorb Easy Plants
# 9997  B000ICJ8DA                    Snoozer Lookout II Pet Car Seat
# 9998  B000Q7AH3W                        Omega Paw Tricky Treat Ball
# 9999  B000ES3YFG  Thera-Band Exercise Tubing - Latex Tubing - 10...
#
#               userId        Time  \
# 0     A2L6QTQQI13LZG  1344211200
# 1      A2HJUOZ9R9K4F  1344211200
# 2     A14PK96LL78NN3  1344211200
# 3     A2UW73HU9UMOTY  1344211200
# 4     A1Q99RNV0TKW8R  1344211200
# ...              ...         ...
# 9995  A3RUBUKF0YX4C7  1362182400
# 9996  A1O9H18FJG81FS  1362182400
# 9997   A3D96MTZP9C1Y  1362182400
# 9998  A37L6DBOH234BC  1362182400
# 9999  A22VB8EGQMAC21  1362268800
#
#                                                    Text                  Cat1  \
# 0     We've only had it installed about 2 weeks. So ...          pet supplies
# 1     My bunny had a hard time eating this because t...          pet supplies
# 2     would never in a million years have guessed th...  health personal care
# 3     Being the jerky fanatic I am, snackmasters han...  grocery gourmet food
# 4     Wondered how quick my dog would catch on to th...          pet supplies
# ...                                                 ...                   ...
# 9995  Stays on continuously without shutting off! It...  health personal care
# 9996  these look great in our 10 gallon tank- colors...          pet supplies
# 9997  This works great, but needs a better way to at...          pet supplies
# 9998  she absolutely LOVES this thing. I dice up gre...          pet supplies
# 9999  I hurt my neck and went to rehab. They had me ...  health personal care
#
#                             Cat2                                Cat3  \
# 0                           cats                           cat flaps
# 1           bunny rabbit central                                food
# 2                    health care                  massage relaxation
# 3                     snack food                   jerky dried meats
# 4                           dogs                                toys
# ...                          ...                                 ...
# 9995                 health care                      pain relievers
# 9996           fish aquatic pets                      aquarium d cor
# 9997                        dogs            carriers travel products
# 9998                        dogs                                toys
# 9999  medical supplies equipment  occupational physical therapy aids
#
#                                           combined_text
# 0     PetSafe Staywell Pet Door with Clear Hard Flap...
# 1     Kaytee Timothy Cubes, 1-Pound My bunny had a h...
# 2     Body Back Buddy would never in a million years...
# 3     SnackMasters California Style Turkey Jerky Bei...
# 4     Premier Busy Buddy Tug-a-Jug Treat Dispensing ...
# ...                                                 ...
# 9995  Sunbeam 732-500 King Size Heating Pad with Ult...
# 9996  Reef One Biorb Easy Plants these look great in...
# 9997  Snoozer Lookout II Pet Car Seat This works gre...
# 9998  Omega Paw Tricky Treat Ball she absolutely LOV...
# 9999  Thera-Band Exercise Tubing - Latex Tubing - 10...
#
# [10000 rows x 9 columns]

# %%
def merge_rare_categories(df, min_samples=10):
    df = df.copy()
    
    # First, analyze category structure
    cat_structure = {}
    for cat1 in df.Cat1.unique():
        cat_structure[cat1] = {}
        for cat2 in df[df.Cat1 == cat1].Cat2.unique():
            cat_structure[cat1][cat2] = df[
                (df.Cat1 == cat1) & 
                (df.Cat2 == cat2)
            ].Cat3.value_counts()
    
    # Process each parent category separately
    for cat1 in cat_structure:
        print(f"\nProcessing {cat1}...")
        
        for cat2, cat3_counts in cat_structure[cat1].items():
            rare_cats = cat3_counts[cat3_counts < min_samples].index
            
            if len(rare_cats) == 0:
                continue
                
            print(f"\n  Processing {len(rare_cats)} rare categories under '{cat2}'")
            
            non_rare = cat3_counts[cat3_counts >= min_samples].index
            
            if len(non_rare) == 0:
                new_cat = f"{cat2} other"
                df.loc[
                    (df.Cat2 == cat2) & 
                    (df.Cat3.isin(rare_cats)), 
                    'Cat3'
                ] = new_cat
                print(f"    Merged all rare categories to '{new_cat}'")
                continue
            
            for rare_cat in rare_cats:
                rare_samples = df[df.Cat3 == rare_cat]
                
                if len(rare_samples) < 5:
                    new_cat = f"{cat2} other"
                else:
                    try:
                        rare_text = ' '.join(rare_samples.text_combined)
                        non_rare_text = df[
                            (df.Cat2 == cat2) & 
                            (df.Cat3.isin(non_rare))
                        ].groupby('Cat3')['text_combined'].agg(' '.join)
                        
                        tfidf = TfidfVectorizer(max_features=1000)
                        non_rare_vecs = tfidf.fit_transform(non_rare_text)
                        rare_vec = tfidf.transform([rare_text])
                        
                        sims = cosine_similarity(rare_vec, non_rare_vecs)[0]
                        
                        if sims.max() > 0.3:  # Increased similarity threshold
                            new_cat = non_rare_text.index[sims.argmax()]
                        else:
                            new_cat = f"{cat2} other"
                    except:
                        new_cat = f"{cat2} other"
                
                df.loc[df.Cat3 == rare_cat, 'Cat3'] = new_cat
                print(f"    Merged '{rare_cat}' ({len(rare_samples)} samples) -> '{new_cat}'")
    
    return df

# %%
CATEGORY_RULES = {
    'health personal care': {
        'min_samples': 15,
        'min_similarity': 0.6,
        'allowed_merges': ['health', 'medical', 'personal care']
    },
    'toys games': {
        'min_samples': 8,
        'min_similarity': 0.4,
        'allowed_merges': ['toys', 'games', 'play']
    },
    'grocery gourmet food': {
        'min_samples': 10,
        'min_similarity': 0.5,
        'allowed_merges': ['food', 'grocery', 'snack', 'beverage']
    },
    'beauty': {
        'min_samples': 12,
        'min_similarity': 0.55,
        'allowed_merges': ['beauty', 'skin', 'hair', 'makeup']
    },
    'pet supplies': {
        'min_samples': 8,
        'min_similarity': 0.45,
        'allowed_merges': ['pet', 'animal', 'supplies']
    },
    'baby products': {
        'min_samples': 10,
        'min_similarity': 0.5,
        'allowed_merges': ['baby', 'infant', 'child']
    }
}

# %%
def clean_text(text):
    """Enhanced text cleaning"""
    if pd.isna(text): 
        return ''
    text = str(text).lower().strip()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
def calculate_similarity_score(df, cat1, cat2, cat_type):
    """
    Calculate similarity between categories with improved metrics
    """
    cat1_products = df[df['Cat3'] == cat1]
    cat2_products = df[df['Cat3'] == cat2]
    
    if len(cat1_products) == 0 or len(cat2_products) == 0:
        return 0.0
    cat1_text = ' '.join(cat1_products['Title'] * 2 + ' ' + cat1_products['Text'])
    cat2_text = ' '.join(cat2_products['Title'] * 2 + ' ' + cat2_products['Text'])
    
    try:
        tfidf = TfidfVectorizer(max_features=1000)
        vectors = tfidf.fit_transform([cat1_text, cat2_text])
        text_similarity = cosine_similarity(vectors)[0][1]
    except:
        text_similarity = 0.0
    
    name_similarity = len(set(cat1.split()) & set(cat2.split())) / \
                     len(set(cat1.split()) | set(cat2.split()))
    
    same_parent = df[df['Cat3'] == cat1]['Cat2'].iloc[0] == \
                 df[df['Cat3'] == cat2]['Cat2'].iloc[0]
    parent_bonus = 0.2 if same_parent else 0.0
    
    rules = CATEGORY_RULES.get(cat_type, {
        'min_similarity': 0.5,
        'allowed_merges': []
    })
    
    allowed_terms = rules['allowed_merges']
    keyword_match = any(term in cat1 or term in cat2 for term in allowed_terms)
    keyword_bonus = 0.1 if keyword_match else 0.0
    final_score = (0.6 * text_similarity + 
                  0.2 * name_similarity + 
                  parent_bonus + 
                  keyword_bonus)
    
    return final_score

# %%
def find_best_merge_target(df, rare_cat, cat_type, existing_cats, min_similarity):
    """
    Find the best category to merge with
    """
    similarities = []
    
    for target_cat in existing_cats:
        if target_cat.endswith('other'):
            continue
            
        similarity = calculate_similarity_score(df, rare_cat, target_cat, cat_type)
        similarities.append((target_cat, similarity))
    

    similarities.sort(key=lambda x: x[1], reverse=True)
    if similarities and similarities[0][1] >= min_similarity:
        return similarities[0]
    
    return None, 0.0

# %%
def merge_rare_categories(df, verbose=True):
    """
    Improved category merging with better handling
    """
    print("Starting improved category merging...")
    df = df.copy()
    merges = []
    for cat_type in df['Cat1'].unique():
        if verbose:
            print(f"\nProcessing {cat_type}...")
        
        rules = CATEGORY_RULES.get(cat_type, {
            'min_samples': 10,
            'min_similarity': 0.5,
            'allowed_merges': []
        })
        
        for cat2 in df[df['Cat1'] == cat_type]['Cat2'].unique():
            # Get category counts
            cat3_counts = df[
                (df['Cat1'] == cat_type) & 
                (df['Cat2'] == cat2)
            ]['Cat3'].value_counts()
        
            rare_cats = cat3_counts[cat3_counts < rules['min_samples']]
            
            if len(rare_cats) == 0:
                continue
                
            if verbose:
                print(f"\n  Processing {len(rare_cats)} rare categories under '{cat2}'")
            
            non_rare_cats = set(cat3_counts[cat3_counts >= rules['min_samples']].index)
            
            for rare_cat in rare_cats.index:
                n_samples = rare_cats[rare_cat]
                if n_samples < 5:
                    new_cat = f"{cat2} other"
                    merge_type = "other (very rare)"
                else:
                    similar_cat, similarity = find_best_merge_target(
                        df, rare_cat, cat_type, non_rare_cats, 
                        rules['min_similarity']
                    )
                    
                    if similar_cat:
                        new_cat = similar_cat
                        merge_type = f"similar (score: {similarity:.2f})"
                    else:
                        new_cat = f"{cat2} other"
                        merge_type = "other (no good match)"
                
                df.loc[
                    (df['Cat1'] == cat_type) & 
                    (df['Cat2'] == cat2) & 
                    (df['Cat3'] == rare_cat),
                    'Cat3'
                ] = new_cat
                
                merges.append({
                    'cat1': cat_type,
                    'cat2': cat2,
                    'old_cat3': rare_cat,
                    'new_cat3': new_cat,
                    'samples': n_samples,
                    'merge_type': merge_type
                })
                
                if verbose:
                    print(f"    Merged '{rare_cat}' ({n_samples} samples) -> '{new_cat}' [{merge_type}]")
    
    merge_df = pd.DataFrame(merges)
    
    if verbose:
        print("\nMerge Summary:")
        print(f"Total merges: {len(merges)}")
        print("\nMerge types:")
        print(merge_df['merge_type'].value_counts())
        
        print("\nFinal category counts:")
        for cat1 in df['Cat1'].unique():
            n_cat2 = len(df[df['Cat1'] == cat1]['Cat2'].unique())
            n_cat3 = len(df[df['Cat1'] == cat1]['Cat3'].unique())
            print(f"{cat1}: {n_cat2} Cat2, {n_cat3} Cat3")
    
    return df, merge_df

print("Initial category counts:")
for cat1 in df['Cat1'].unique():
    n_cat2 = len(df[df['Cat1'] == cat1]['Cat2'].unique())
    n_cat3 = len(df[df['Cat1'] == cat1]['Cat3'].unique())
    print(f"{cat1}: {n_cat2} Cat2, {n_cat3} Cat3")

cleaned_df, merge_report = merge_rare_categories(df)
cleaned_df.to_csv('cleaned_categories_improved.csv', index=False)
merge_report.to_csv('category_merges_report.csv', index=False)
# Out:
# Initial category counts:
# pet supplies: 6 Cat2, 35 Cat3
# health personal care: 7 Cat2, 81 Cat3
# grocery gourmet food: 16 Cat2, 106 Cat3
# toys games: 17 Cat2, 151 Cat3
# beauty: 6 Cat2, 57 Cat3
# baby products: 12 Cat2, 86 Cat3
# Starting improved category merging...
#
# Processing pet supplies...
#
#   Processing 1 rare categories under 'cats'
#     Merged 'collars' (3 samples) -> 'cats other' [other (very rare)]
#
#   Processing 5 rare categories under 'bunny rabbit central'
#     Merged 'food' (3 samples) -> 'bunny rabbit central other' [other (very rare)]
#     Merged 'rabbit hutches' (3 samples) -> 'bunny rabbit central other' [other (very rare)]
#     Merged 'carriers' (2 samples) -> 'bunny rabbit central other' [other (very rare)]
#     Merged 'feeding watering supplies' (1 samples) -> 'bunny rabbit central other' [other (very rare)]
#     Merged 'treats' (1 samples) -> 'bunny rabbit central other' [other (very rare)]
#
#   Processing 2 rare categories under 'birds'
#     Merged 'health supplies' (1 samples) -> 'birds other' [other (very rare)]
#     Merged 'treats' (1 samples) -> 'birds other' [other (very rare)]
#
#   Processing 8 rare categories under 'fish aquatic pets'
#     Merged 'test kits' (5 samples) -> 'pumps filters' [similar (score: 0.57)]
#     Merged 'health supplies' (4 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'aquarium heaters' (3 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'aquarium starter kits' (2 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'automatic feeders' (1 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'aquarium hoods' (1 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'hydrometers' (1 samples) -> 'fish aquatic pets other' [other (very rare)]
#     Merged 'breeding tanks' (1 samples) -> 'fish aquatic pets other' [other (very rare)]
#
#   Processing 6 rare categories under 'small animals'
#     Merged 'food' (6 samples) -> 'small animals other' [other (no good match)]
#     Merged 'houses habitats' (1 samples) -> 'small animals other' [other (very rare)]
#     Merged 'feeding watering supplies' (1 samples) -> 'small animals other' [other (very rare)]
#     Merged 'exercise wheels' (1 samples) -> 'small animals other' [other (very rare)]
#     Merged 'treats' (1 samples) -> 'small animals other' [other (very rare)]
#     Merged 'collars' (1 samples) -> 'small animals other' [other (very rare)]
#
# Processing health personal care...
#
#   Processing 20 rare categories under 'health care'
#     Merged 'therapeutic skin care' (14 samples) -> 'foot care' [similar (score: 0.63)]
#     Merged 'diabetes' (13 samples) -> 'alternative medicine' [similar (score: 0.64)]
#     Merged 'smoking cessation' (8 samples) -> 'health care other' [other (no good match)]
#     Merged 'thermometers' (6 samples) -> 'women s health' [similar (score: 0.63)]
#     Merged 'stimulants' (3 samples) -> 'health care other' [other (very rare)]
#     Merged 'braces' (2 samples) -> 'health care other' [other (very rare)]
#     Merged 'thermometer accessories' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'highchairs booster seats' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'licorice' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'pegged puzzles' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'trains accessories' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'beds accessories' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'bedding' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'craft kits' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'laundry' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'litter housebreaking' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'live indoor plants' (1 samples) -> 'health care other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'health care other' [other (very rare)]
#
#   Processing 9 rare categories under 'household supplies'
#     Merged 'dishwashing' (13 samples) -> 'household cleaning' [similar (score: 0.65)]
#     Merged 'air fresheners' (8 samples) -> 'household cleaning' [similar (score: 0.65)]
#     Merged 'daily living aids' (4 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'vitamins supplements' (2 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'dolls' (2 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'health monitors' (1 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'fresh fruits' (1 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'styling products' (1 samples) -> 'household supplies other' [other (very rare)]
#     Merged 'beanbags foot bags' (1 samples) -> 'household supplies other' [other (very rare)]
#
#   Processing 8 rare categories under 'personal care'
#     Merged 'feminine care' (13 samples) -> 'oral hygiene' [similar (score: 0.62)]
#     Merged 'foot care' (9 samples) -> 'personal care other' [other (no good match)]
#     Merged 'ear care' (8 samples) -> 'shaving hair removal' [similar (score: 0.60)]
#     Merged 'body art' (2 samples) -> 'personal care other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'personal care other' [other (very rare)]
#     Merged 'baby gyms playmats' (1 samples) -> 'personal care other' [other (very rare)]
#     Merged 'mirrors' (1 samples) -> 'personal care other' [other (very rare)]
#     Merged 'women s' (1 samples) -> 'personal care other' [other (very rare)]
#
#   Processing 4 rare categories under 'nutrition wellness'
#     Merged 'foot care' (1 samples) -> 'nutrition wellness other' [other (very rare)]
#     Merged 'men s' (1 samples) -> 'nutrition wellness other' [other (very rare)]
#     Merged 'health monitors' (1 samples) -> 'nutrition wellness other' [other (very rare)]
#     Merged 'bottle feeding' (1 samples) -> 'nutrition wellness other' [other (very rare)]
#
#   Processing 3 rare categories under 'baby child care'
#     Merged 'personal care' (3 samples) -> 'baby child care other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'baby child care other' [other (very rare)]
#     Merged 'health monitors' (1 samples) -> 'baby child care other' [other (very rare)]
#
#   Processing 8 rare categories under 'medical supplies equipment'
#     Merged 'occupational physical therapy aids' (13 samples) -> 'health monitors' [similar (score: 0.70)]
#     Merged 'tests' (3 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'alternative medicine' (2 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'household batteries' (1 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'carriers travel products' (1 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'pools water fun' (1 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'radio control' (1 samples) -> 'medical supplies equipment other' [other (very rare)]
#     Merged 'drawing painting supplies' (1 samples) -> 'medical supplies equipment other' [other (very rare)]
#
#   Processing 8 rare categories under 'sexual wellness'
#     Merged 'bondage gear accessories' (5 samples) -> 'sexual wellness other' [other (no good match)]
#     Merged 'novelties' (2 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'body' (2 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'sexual enhancers' (1 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'paper plastic' (1 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'sex furniture' (1 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'sensual delights' (1 samples) -> 'sexual wellness other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'sexual wellness other' [other (very rare)]
#
# Processing grocery gourmet food...
#
#   Processing 16 rare categories under 'snack food'
#     Merged 'cookies' (7 samples) -> 'crackers' [similar (score: 0.53)]
#     Merged 'fruit leather' (6 samples) -> 'snack food other' [other (no good match)]
#     Merged 'jerky dried meats' (4 samples) -> 'snack food other' [other (very rare)]
#     Merged 'chips crisps' (4 samples) -> 'snack food other' [other (very rare)]
#     Merged 'puffed snacks' (4 samples) -> 'snack food other' [other (very rare)]
#     Merged 'party mix' (3 samples) -> 'snack food other' [other (very rare)]
#     Merged 'salsas' (2 samples) -> 'snack food other' [other (very rare)]
#     Merged 'pretzels' (2 samples) -> 'snack food other' [other (very rare)]
#     Merged 'pork rinds' (2 samples) -> 'snack food other' [other (very rare)]
#     Merged 'chips' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'dried fruit' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'food' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'health supplies' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'dried fruit raisins' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'face' (1 samples) -> 'snack food other' [other (very rare)]
#     Merged 'figures' (1 samples) -> 'snack food other' [other (very rare)]
#
#   Processing 10 rare categories under 'pantry staples'
#     Merged 'dried beans' (9 samples) -> 'cooking baking supplies' [similar (score: 0.58)]
#     Merged 'jams' (8 samples) -> 'cooking baking supplies' [similar (score: 0.59)]
#     Merged 'pasta noodles' (6 samples) -> 'canned jarred food' [similar (score: 0.65)]
#     Merged 'packaged meals side dishes' (4 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'condiments' (2 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'feminine care' (1 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'face' (1 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'model building kits tools' (1 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'oils' (1 samples) -> 'pantry staples other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'pantry staples other' [other (very rare)]
#
#   Processing 12 rare categories under 'cooking baking supplies'
#     Merged 'baking mixes' (5 samples) -> 'cooking baking supplies other' [other (no good match)]
#     Merged 'chocolate' (3 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'sugars sweeteners' (3 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'nuts seeds' (2 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'dessert toppings' (2 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'flours meals' (2 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'extracts flavoring' (2 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'food coloring' (2 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'coatings batters' (1 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'sugar substitutes' (1 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'health monitors' (1 samples) -> 'cooking baking supplies other' [other (very rare)]
#     Merged 'chocolate bars' (1 samples) -> 'cooking baking supplies other' [other (very rare)]
#
#   Processing 23 rare categories under 'candy chocolate'
#     Merged 'gummy candies' (9 samples) -> 'hard candies' [similar (score: 0.65)]
#     Merged 'licorice' (8 samples) -> 'hard candies' [similar (score: 0.50)]
#     Merged 'mints' (8 samples) -> 'hard candies' [similar (score: 0.50)]
#     Merged 'gummy candy' (7 samples) -> 'hard candies' [similar (score: 0.65)]
#     Merged 'gum' (7 samples) -> 'hard candies' [similar (score: 0.52)]
#     Merged 'taffy' (6 samples) -> 'hard candies' [similar (score: 0.58)]
#     Merged 'caramels' (6 samples) -> 'candy chocolate other' [other (no good match)]
#     Merged 'chewing gum' (4 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'chocolate assortments' (3 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'jelly beans' (3 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'chocolate covered fruit' (3 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'chocolate truffles' (2 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'bars' (2 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'chocolate covered nuts' (2 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'nut clusters' (2 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'fruits' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'nutrition bars drinks' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'fruit leather' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'fudge' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'coffee' (1 samples) -> 'candy chocolate other' [other (very rare)]
#     Merged 'chips crisps' (1 samples) -> 'candy chocolate other' [other (very rare)]
#
#   Processing 6 rare categories under 'beverages'
#     Merged 'coconut water' (8 samples) -> 'beverages other' [other (no good match)]
#     Merged 'powdered drink mixes' (4 samples) -> 'beverages other' [other (very rare)]
#     Merged 'energy drinks' (4 samples) -> 'beverages other' [other (very rare)]
#     Merged 'soft drinks' (3 samples) -> 'beverages other' [other (very rare)]
#     Merged 'water' (1 samples) -> 'beverages other' [other (very rare)]
#     Merged 'sports drinks' (1 samples) -> 'beverages other' [other (very rare)]
#
#   Processing 1 rare categories under 'breakfast foods'
#     Merged 'toaster pastries' (2 samples) -> 'breakfast foods other' [other (very rare)]
#
#   Processing 1 rare categories under 'fresh flowers live indoor plants'
#     Merged 'fresh cut flowers' (3 samples) -> 'fresh flowers live indoor plants other' [other (very rare)]
#
#   Processing 1 rare categories under 'sauces dips'
#     Merged 'dips' (2 samples) -> 'sauces dips other' [other (very rare)]
#
#   Processing 4 rare categories under 'dairy eggs'
#     Merged 'milk' (5 samples) -> 'dairy eggs other' [other (no good match)]
#     Merged 'coffee' (2 samples) -> 'dairy eggs other' [other (very rare)]
#     Merged 'cheese' (2 samples) -> 'dairy eggs other' [other (very rare)]
#     Merged 'eggs' (1 samples) -> 'dairy eggs other' [other (very rare)]
#
#   Processing 6 rare categories under 'breads bakery'
#     Merged 'cookies' (9 samples) -> 'breads bakery other' [other (no good match)]
#     Merged 'fresh baked cookies' (5 samples) -> 'breads bakery other' [other (no good match)]
#     Merged 'cakes' (4 samples) -> 'breads bakery other' [other (very rare)]
#     Merged 'breadsticks' (2 samples) -> 'breads bakery other' [other (very rare)]
#     Merged 'health care' (1 samples) -> 'breads bakery other' [other (very rare)]
#     Merged 'stuffing' (1 samples) -> 'breads bakery other' [other (very rare)]
#
#   Processing 8 rare categories under 'gourmet gifts'
#     Merged 'tea gifts' (4 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'snack gifts' (3 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'chocolate gifts' (3 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'candy gifts' (3 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'seafood gifts' (3 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'meat gifts' (2 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'sauces gifts' (2 samples) -> 'gourmet gifts other' [other (very rare)]
#     Merged 'cheese gifts' (1 samples) -> 'gourmet gifts other' [other (very rare)]
#
#   Processing 2 rare categories under 'produce'
#     Merged 'fresh fruits' (5 samples) -> 'produce other' [other (no good match)]
#     Merged 'fresh vegetables' (2 samples) -> 'produce other' [other (very rare)]
#
#   Processing 1 rare categories under 'meat seafood'
#     Merged 'seafood' (5 samples) -> 'meat seafood other' [other (no good match)]
#
#   Processing 3 rare categories under 'meat poultry'
#     Merged 'first aid' (1 samples) -> 'meat poultry other' [other (very rare)]
#     Merged 'lamb' (1 samples) -> 'meat poultry other' [other (very rare)]
#     Merged 'pork' (1 samples) -> 'meat poultry other' [other (very rare)]
#
#   Processing 2 rare categories under 'baby food'
#     Merged 'cereal' (1 samples) -> 'baby food other' [other (very rare)]
#     Merged 'baby formula' (1 samples) -> 'baby food other' [other (very rare)]
#
# Processing toys games...
#
#   Processing 25 rare categories under 'novelty gag toys'
#     Merged 'prisms kaleidoscopes' (4 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'pretend play' (3 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'wind up toys' (3 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'viewfinders' (3 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'science' (2 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'flying toys' (2 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'vitamins supplements' (2 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'board games' (2 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'litter housebreaking' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'craft kits' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'money banks' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'doll accessories' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'brain teasers' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'daily living aids' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'figures' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'electronic toys' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'teethers' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'scooters wagons' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'novelty spinning tops' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'diaper bags' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'playsets' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'pumps filters' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#     Merged 'alternative medicine' (1 samples) -> 'novelty gag toys other' [other (very rare)]
#
#   Processing 1 rare categories under 'action toy figures'
#     Merged 'statues' (1 samples) -> 'action toy figures other' [other (very rare)]
#
#   Processing 8 rare categories under 'stuffed animals plush'
#     Merged 'puppets' (7 samples) -> 'animals figures' [similar (score: 0.61)]
#     Merged 'teddy bears' (4 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'plush puppets' (4 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'board games' (2 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'flash cards' (1 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'd puzzles' (1 samples) -> 'stuffed animals plush other' [other (very rare)]
#     Merged 'plush backpacks purses' (1 samples) -> 'stuffed animals plush other' [other (very rare)]
#
#   Processing 15 rare categories under 'baby toddler toys'
#     Merged 'balls' (5 samples) -> 'push pull toys' [similar (score: 0.70)]
#     Merged 'pretend play' (4 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'teaching clocks' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'electronic toys' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'household batteries' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'activity play centers' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'scooters wagons' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'toys' (2 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'hands nails' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'doll accessories' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'trains accessories' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'radio control' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'dolls' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#     Merged 'jigsaw puzzles' (1 samples) -> 'baby toddler toys other' [other (very rare)]
#
#   Processing 3 rare categories under 'dolls accessories'
#     Merged 'dollhouses' (5 samples) -> 'dolls' [similar (score: 0.59)]
#     Merged 'dollhouse accessories' (5 samples) -> 'doll accessories' [similar (score: 0.69)]
#     Merged 'playsets' (3 samples) -> 'dolls accessories other' [other (very rare)]
#
#   Processing 4 rare categories under 'hobbies'
#     Merged 'rockets' (5 samples) -> 'model building kits tools' [similar (score: 0.49)]
#     Merged 'scaled model vehicles' (5 samples) -> 'model building kits tools' [similar (score: 0.53)]
#     Merged 'scooters wagons' (1 samples) -> 'hobbies other' [other (very rare)]
#     Merged 'coin collecting' (1 samples) -> 'hobbies other' [other (very rare)]
#
#   Processing 16 rare categories under 'games'
#     Merged 'dice gaming dice' (4 samples) -> 'games other' [other (very rare)]
#     Merged 'game room games' (4 samples) -> 'games other' [other (very rare)]
#     Merged 'floor games' (3 samples) -> 'games other' [other (very rare)]
#     Merged 'game collections' (3 samples) -> 'games other' [other (very rare)]
#     Merged 'tile games' (2 samples) -> 'games other' [other (very rare)]
#     Merged 'battling tops' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'seafood gifts' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'paper plastic' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'scooters wagons' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'push pull toys' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'model building kits tools' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'geography' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'cheese gifts' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'cat flaps' (1 samples) -> 'games other' [other (very rare)]
#     Merged 'canned jarred food' (1 samples) -> 'games other' [other (very rare)]
#
#   Processing 16 rare categories under 'arts crafts'
#     Merged 'easels' (7 samples) -> 'craft kits' [similar (score: 0.56)]
#     Merged 'drawing sketching tablets' (3 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'aprons smocks' (3 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'stickers' (2 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'toys' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'daily living aids' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'bath toys' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'board games' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'dolls' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'blackboards whiteboards' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'shape sorters' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'women s' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'household cleaning' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'beds furniture' (1 samples) -> 'arts crafts other' [other (very rare)]
#     Merged 'nails' (1 samples) -> 'arts crafts other' [other (very rare)]
#
#   Processing 39 rare categories under 'electronics for kids'
#     Merged 'electronic pets' (6 samples) -> 'electronic toys' [similar (score: 0.69)]
#     Merged 'music players karaoke' (4 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'training behavior aids' (3 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'dolls' (2 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'oral hygiene' (2 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'alternative medicine' (2 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'board games' (2 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'toys' (2 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'playsets' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'aquarium lights' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'pain relievers' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'plug play video games' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'activity play centers' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'rockets' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'cameras camcorders' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'scooters wagons' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'grooming' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'pools water fun' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'carriers travel products' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'beds furniture' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'play tents tunnels' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'teethers' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'thermometers' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'feeding watering supplies' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'card games' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'push pull toys' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'habitats' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'puppets' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'highchairs booster seats' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'sun protection' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'deodorants antiperspirants' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'household batteries' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'personal video players accessories' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'tests' (1 samples) -> 'electronics for kids other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'electronics for kids other' [other (very rare)]
#
#   Processing 1 rare categories under 'vehicles remote control'
#     Merged 'die cast vehicles' (1 samples) -> 'vehicles remote control other' [other (very rare)]
#
#   Processing 31 rare categories under 'grown up toys'
#     Merged 'board games' (4 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'action toy figures' (3 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'science' (3 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'puzzles' (3 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'daily living aids' (2 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'scaled model vehicles' (2 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'standard playing card decks' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'building sets' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'model building kits tools' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'trains accessories' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'braces' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'feminine care' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'stacking games' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'doll accessories' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'push pull toys' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'toys' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'craft kits' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'oral hygiene' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'household batteries' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'figures' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'scooters wagons' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'health care' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'flash cards' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'litter housebreaking' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'puppets' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'play vehicles' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'tea' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'household cleaning' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'playsets' (1 samples) -> 'grown up toys other' [other (very rare)]
#     Merged 'die cast toy vehicles' (1 samples) -> 'grown up toys other' [other (very rare)]
#
#   Processing 1 rare categories under 'dress up pretend play'
#     Merged 'beauty fashion' (1 samples) -> 'dress up pretend play other' [other (very rare)]
#
#   Processing 8 rare categories under 'building toys'
#     Merged 'marble runs' (3 samples) -> 'building toys other' [other (very rare)]
#     Merged 'music sound' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'trains accessories' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'basic life skills toys' (1 samples) -> 'building toys other' [other (very rare)]
#     Merged 'nursery d cor' (1 samples) -> 'building toys other' [other (very rare)]
#
#   Processing 13 rare categories under 'sports outdoor play'
#     Merged 'gym sets swings' (7 samples) -> 'play tents tunnels' [similar (score: 0.58)]
#     Merged 'blasters foam play' (7 samples) -> 'play tents tunnels' [similar (score: 0.65)]
#     Merged 'pogo sticks hoppers' (4 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'sandboxes accessories' (2 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'ball pits accessories' (2 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'kites wind spinners' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'die cast toy vehicles' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'beanbags foot bags' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'massage relaxation' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'bathroom aids safety' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'gardening tools' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#     Merged 'beds furniture' (1 samples) -> 'sports outdoor play other' [other (very rare)]
#
#   Processing 7 rare categories under 'puzzles'
#     Merged 'd puzzles' (4 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'puzzle play mats' (2 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'standard playing card decks' (1 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'electronic toys' (1 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'dollhouses' (1 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'blocks' (1 samples) -> 'puzzles other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'puzzles other' [other (very rare)]
#
#   Processing 30 rare categories under 'learning education'
#     Merged 'basic life skills toys' (6 samples) -> 'science' [similar (score: 0.58)]
#     Merged 'mathematics counting' (5 samples) -> 'science' [similar (score: 0.54)]
#     Merged 'pretend play' (5 samples) -> 'science' [similar (score: 0.64)]
#     Merged 'jigsaw puzzles' (5 samples) -> 'science' [similar (score: 0.45)]
#     Merged 'pegged puzzles' (3 samples) -> 'learning education other' [other (very rare)]
#     Merged 'accessories' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'stacking nesting toys' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'shape sorters' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'board games' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'toys' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'blocks' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'trains accessories' (2 samples) -> 'learning education other' [other (very rare)]
#     Merged 'activity play centers' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'furniture' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'houses' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'teethers' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'toy balls' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'first aid' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'bedding' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'die cast vehicles' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'electronics' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'push pull toys' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'activity centers entertainers' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'face' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'dolls' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'drawing sketching tablets' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'pogo sticks hoppers' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'novelty gag toys' (1 samples) -> 'learning education other' [other (very rare)]
#     Merged 'craft kits' (1 samples) -> 'learning education other' [other (very rare)]
#
# Processing beauty...
#
#   Processing 8 rare categories under 'fragrance'
#     Merged 'deodorants antiperspirants' (2 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'daily living aids' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'household cleaning' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'nails' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'children s' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'grooming' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'sleep snoring' (1 samples) -> 'fragrance other' [other (very rare)]
#     Merged 'sports' (1 samples) -> 'fragrance other' [other (very rare)]
#
#   Processing 21 rare categories under 'skin care'
#     Merged 'eyes' (11 samples) -> 'skin care other' [other (no good match)]
#     Merged 'maternity' (5 samples) -> 'skin care other' [other (no good match)]
#     Merged 'vitamins supplements' (4 samples) -> 'skin care other' [other (very rare)]
#     Merged 'sets' (2 samples) -> 'skin care other' [other (very rare)]
#     Merged 'styling products' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'health supplies' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'hair scalp treatments' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'ear care' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'bottle feeding' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'coconut water' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'massage relaxation' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'alternative medicine' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'extracts flavoring' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'juices' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'sleep snoring' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'daily living aids' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'board games' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'household cleaning' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'foot care' (1 samples) -> 'skin care other' [other (very rare)]
#     Merged 'men s' (1 samples) -> 'skin care other' [other (very rare)]
#
#   Processing 3 rare categories under 'makeup'
#     Merged 'makeup remover' (9 samples) -> 'eyes' [similar (score: 0.68)]
#     Merged 'body' (7 samples) -> 'face' [similar (score: 0.76)]
#     Merged 'cleansers' (1 samples) -> 'makeup other' [other (very rare)]
#
#   Processing 8 rare categories under 'hair care'
#     Merged 'shampoo plus conditioner' (5 samples) -> 'shampoo conditioner sets' [similar (score: 0.65)]
#     Merged 'hair relaxers' (2 samples) -> 'hair care other' [other (very rare)]
#     Merged 'coffee' (1 samples) -> 'hair care other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'hair care other' [other (very rare)]
#     Merged 'men s' (1 samples) -> 'hair care other' [other (very rare)]
#     Merged 'grooming' (1 samples) -> 'hair care other' [other (very rare)]
#     Merged 'hands nails' (1 samples) -> 'hair care other' [other (very rare)]
#     Merged 'shaving hair removal' (1 samples) -> 'hair care other' [other (very rare)]
#
#   Processing 9 rare categories under 'bath body'
#     Merged 'bathing accessories' (11 samples) -> 'cleansers' [similar (score: 0.62)]
#     Merged 'scrubs body treatments' (10 samples) -> 'cleansers' [similar (score: 0.66)]
#     Merged 'styling tools' (8 samples) -> 'bath body other' [other (no good match)]
#     Merged 'face' (2 samples) -> 'bath body other' [other (very rare)]
#     Merged 'sets' (2 samples) -> 'bath body other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'bath body other' [other (very rare)]
#     Merged 'shampoos' (1 samples) -> 'bath body other' [other (very rare)]
#     Merged 'men s' (1 samples) -> 'bath body other' [other (very rare)]
#     Merged 'trading card games' (1 samples) -> 'bath body other' [other (very rare)]
#
#   Processing 6 rare categories under 'tools accessories'
#     Merged 'bags cases' (7 samples) -> 'makeup brushes tools' [similar (score: 0.65)]
#     Merged 'cotton swabs' (3 samples) -> 'tools accessories other' [other (very rare)]
#     Merged 'hair coloring tools' (2 samples) -> 'tools accessories other' [other (very rare)]
#     Merged 'facial steamers' (2 samples) -> 'tools accessories other' [other (very rare)]
#     Merged 'braces' (1 samples) -> 'tools accessories other' [other (very rare)]
#     Merged 'skin care' (1 samples) -> 'tools accessories other' [other (very rare)]
#
# Processing baby products...
#
#   Processing 22 rare categories under 'nursery'
#     Merged 'backpacks carriers' (3 samples) -> 'nursery other' [other (very rare)]
#     Merged 'craft kits' (3 samples) -> 'nursery other' [other (very rare)]
#     Merged 'toys' (2 samples) -> 'nursery other' [other (very rare)]
#     Merged 'alternative medicine' (2 samples) -> 'nursery other' [other (very rare)]
#     Merged 'beds furniture' (2 samples) -> 'nursery other' [other (very rare)]
#     Merged 'bottle feeding' (2 samples) -> 'nursery other' [other (very rare)]
#     Merged 'baby gyms playmats' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'drawing painting supplies' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'bathing tubs seats' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'face' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'gates doorways' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'eye care' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'potties seats' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'pretend play' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'accessories' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'electronic toys' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'eyes' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'health care' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'monitors' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'playards' (1 samples) -> 'nursery other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'nursery other' [other (very rare)]
#
#   Processing 7 rare categories under 'diapering'
#     Merged 'changing table pads covers' (9 samples) -> 'diapering other' [other (no good match)]
#     Merged 'diaper stackers caddies' (4 samples) -> 'diapering other' [other (very rare)]
#     Merged 'diaper pails refills' (4 samples) -> 'diapering other' [other (very rare)]
#     Merged 'cloth diapers' (2 samples) -> 'diapering other' [other (very rare)]
#     Merged 'diaper changing kits' (1 samples) -> 'diapering other' [other (very rare)]
#     Merged 'carriers travel products' (1 samples) -> 'diapering other' [other (very rare)]
#     Merged 'baby seats' (1 samples) -> 'diapering other' [other (very rare)]
#
#   Processing 20 rare categories under 'gifts'
#     Merged 'keepsakes' (3 samples) -> 'gifts other' [other (very rare)]
#     Merged 'albums' (2 samples) -> 'gifts other' [other (very rare)]
#     Merged 'incontinence' (2 samples) -> 'gifts other' [other (very rare)]
#     Merged 'toy banks' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'collars' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'aquarium lights' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'accessories' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'animals figures' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'beds furniture' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'nails' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'chocolate gifts' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'vitamins supplements' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'eyes' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'dolls' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'music sound' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'activity centers entertainers' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'cough cold' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'play tents tunnels' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'toys' (1 samples) -> 'gifts other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'gifts other' [other (very rare)]
#
#   Processing 2 rare categories under 'potty training'
#     Merged 'step stools' (3 samples) -> 'potty training other' [other (very rare)]
#     Merged 'training pants' (3 samples) -> 'potty training other' [other (very rare)]
#
#   Processing 9 rare categories under 'safety'
#     Merged 'kitchen safety' (9 samples) -> 'safety other' [other (no good match)]
#     Merged 'monitors' (8 samples) -> 'gates doorways' [similar (score: 0.56)]
#     Merged 'edge corner guards' (7 samples) -> 'gates doorways' [similar (score: 0.57)]
#     Merged 'electrical safety' (7 samples) -> 'safety other' [other (no good match)]
#     Merged 'bathroom safety' (4 samples) -> 'safety other' [other (very rare)]
#     Merged 'cabinet locks straps' (2 samples) -> 'safety other' [other (very rare)]
#     Merged 'harnesses leashes' (1 samples) -> 'safety other' [other (very rare)]
#     Merged 'sleep positioners' (1 samples) -> 'safety other' [other (very rare)]
#     Merged 'collars' (1 samples) -> 'safety other' [other (very rare)]
#
#   Processing 5 rare categories under 'feeding'
#     Merged 'pillows stools' (6 samples) -> 'highchairs booster seats' [similar (score: 0.50)]
#     Merged 'pacifiers accessories' (4 samples) -> 'feeding other' [other (very rare)]
#     Merged 'food' (3 samples) -> 'feeding other' [other (very rare)]
#     Merged 'braces' (2 samples) -> 'feeding other' [other (very rare)]
#     Merged 'science' (1 samples) -> 'feeding other' [other (very rare)]
#
#   Processing 5 rare categories under 'strollers'
#     Merged 'tandem' (9 samples) -> 'strollers other' [other (no good match)]
#     Merged 'accessories' (7 samples) -> 'strollers other' [other (no good match)]
#     Merged 'standard' (3 samples) -> 'strollers other' [other (very rare)]
#     Merged 'lightweight' (2 samples) -> 'strollers other' [other (very rare)]
#     Merged 'backpacks carriers' (1 samples) -> 'strollers other' [other (very rare)]
#
#   Processing 3 rare categories under 'gear'
#     Merged 'baby gyms playmats' (7 samples) -> 'backpacks carriers' [similar (score: 0.71)]
#     Merged 'baby seats' (1 samples) -> 'gear other' [other (very rare)]
#     Merged 'sports supplements' (1 samples) -> 'gear other' [other (very rare)]
#
#   Processing 1 rare categories under 'health baby care'
#     Merged 'sun protection' (1 samples) -> 'health baby care other' [other (very rare)]
#
#   Processing 12 rare categories under 'bathing skin care'
#     Merged 'bathing tubs seats' (8 samples) -> 'skin care' [similar (score: 0.54)]
#     Merged 'grooming healthcare kits' (7 samples) -> 'skin care' [similar (score: 0.55)]
#     Merged 'soaps cleansers' (6 samples) -> 'skin care' [similar (score: 0.57)]
#     Merged 'body' (2 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'vitamins supplements' (2 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'litter housebreaking' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'backpacks carriers' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'shampoo' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'trains accessories' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'massage relaxation' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'styling tools' (1 samples) -> 'bathing skin care other' [other (very rare)]
#     Merged 'pain relievers' (1 samples) -> 'bathing skin care other' [other (very rare)]
#
#   Processing 1 rare categories under 'car seats accessories'
#     Merged 'car seats' (1 samples) -> 'car seats accessories other' [other (very rare)]
#
# Merge Summary:
# Total merges: 538
#
# Merge types:
# merge_type
# other (very rare)        471
# other (no good match)     21
# similar (score: 0.65)      8
# similar (score: 0.58)      4
# similar (score: 0.57)      3
# similar (score: 0.50)      3
# similar (score: 0.62)      2
# similar (score: 0.59)      2
# similar (score: 0.54)      2
# similar (score: 0.56)      2
# similar (score: 0.63)      2
# similar (score: 0.69)      2
# similar (score: 0.64)      2
# similar (score: 0.53)      2
# similar (score: 0.70)      2
# similar (score: 0.52)      1
# similar (score: 0.61)      1
# similar (score: 0.60)      1
# similar (score: 0.49)      1
# similar (score: 0.45)      1
# similar (score: 0.68)      1
# similar (score: 0.76)      1
# similar (score: 0.66)      1
# similar (score: 0.71)      1
# similar (score: 0.55)      1
# Name: count, dtype: int64
#
# Final category counts:
# pet supplies: 6 Cat2, 30 Cat3
# health personal care: 7 Cat2, 45 Cat3
# grocery gourmet food: 16 Cat2, 32 Cat3
# toys games: 17 Cat2, 67 Cat3
# beauty: 6 Cat2, 28 Cat3
# baby products: 12 Cat2, 33 Cat3
